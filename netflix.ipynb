# %%
"""🔹 Python EDA Tasks:
📊 Basic Analysis:
Total number of Movies vs TV Shows

Top 10 genres

Content count by country

Year-wise trend of content added

📅 Time-Based:
Most common year of release

Netflix growth over time (date_added)

🎭 Cast & Crew:
Most frequent directors

Frequent actors/actresses (using cast)

🔎 Filtering:
List all Indian Movies

Show all shows with rating "PG-13" released after 2015

Movies longer than 100 minutes

☁️ WordCloud Ideas:
Most used words in movie titles

Common words in descriptions

🔹 Advanced Ideas (Optional):
Group by rating and analyze genre trends

Analyze duration: Are TV shows getting shorter/longer?

Predict if a title is a Movie or TV Show based on features like duration, rating, etc."""

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ladwa\Desktop\forproj\netflix_sample_100.csv")

# %%
df.head()
# Out:
#   show_id   type           title    director              cast  \
# 0   s0001  Movie  Sample Title 1  Director A  Actor 1, Actor 2
# 1   s0002  Movie  Sample Title 2  Director B           Actor 3
# 2   s0003  Movie  Sample Title 3  Director C               NaN
# 3   s0004  Movie  Sample Title 4         NaN  Actor 4, Actor 5
# 4   s0005  Movie  Sample Title 5  Director A  Actor 1, Actor 2
#
#           country  date_added  release_year rating duration  \
# 0   United States  2020-01-01          2018  TV-MA   90 min
# 1           India  2020-01-08          2019     PG   91 min
# 2  United Kingdom  2020-01-15          2020      R   92 min
# 3          Canada  2020-01-22          2021  TV-14   93 min
# 4   United States  2020-01-29          2022   TV-G   94 min
#
#                       listed_in                               description
# 0  Dramas, International Movies  This is a sample description for title 1
# 1                      Comedies  This is a sample description for title 2
# ...

# %%
df.shape
# Out:
# (100, 12)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    show_id     type             title    director              cast  \
# 0    s0001    Movie    Sample Title 1  Director A  Actor 1, Actor 2
# 1    s0002    Movie    Sample Title 2  Director B           Actor 3
# 2    s0003    Movie    Sample Title 3  Director C               NaN
# 3    s0004    Movie    Sample Title 4         NaN  Actor 4, Actor 5
# 4    s0005    Movie    Sample Title 5  Director A  Actor 1, Actor 2
# ..     ...      ...               ...         ...               ...
# 95   s0096  TV Show   Sample Title 96         NaN  Actor 4, Actor 5
# 96   s0097  TV Show   Sample Title 97  Director A  Actor 1, Actor 2
# 97   s0098  TV Show   Sample Title 98  Director B           Actor 3
# 98   s0099  TV Show   Sample Title 99  Director C               NaN
# 99   s0100  TV Show  Sample Title 100         NaN  Actor 4, Actor 5
#
#            country  date_added  release_year rating  duration  \
# ...

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
"""📊 Basic Analysis:
Total number of Movies vs TV Shows

Top 10 genres

Content count by country

Year-wise trend of content added"""

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.head()
# Out:
#   show_id   type           title    director              cast  \
# 0   s0001  Movie  Sample Title 1  Director A  Actor 1, Actor 2
# 1   s0002  Movie  Sample Title 2  Director B           Actor 3
# 2   s0003  Movie  Sample Title 3  Director C               NaN
# 3   s0004  Movie  Sample Title 4         NaN  Actor 4, Actor 5
# 4   s0005  Movie  Sample Title 5  Director A  Actor 1, Actor 2
#
#           country  date_added  release_year rating duration  \
# 0   United States  2020-01-01          2018  TV-MA   90 min
# 1           India  2020-01-08          2019     PG   91 min
# 2  United Kingdom  2020-01-15          2020      R   92 min
# 3          Canada  2020-01-22          2021  TV-14   93 min
# 4   United States  2020-01-29          2022   TV-G   94 min
#
#                       listed_in                               description
# 0  Dramas, International Movies  This is a sample description for title 1
# 1                      Comedies  This is a sample description for title 2
# ...

# %%
#Total number of Movies vs TV Shows
val=df["type"].value_counts().sort_index()
plt.pie(val,labels=val.index,autopct="%1.1f%%")
plt.show()

# %%
import plotly.express as px

# %%
#Top 10 genres
df["listed_in"].value_counts().reset_index().head(10)
# Out:
#                       listed_in  count
# 0  Dramas, International Movies     25
# 1                      Comedies     25
# 2            Action & Adventure     25
# 3                 Documentaries     25

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director        25
# cast            25
# country          0
# date_added       0
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
#Content count by country
df.groupby("country")["show_id"].count()
# Out:
# country
# Canada            25
# India             25
# United Kingdom    25
# United States     25
# Name: show_id, dtype: int64

# %%
#Year-wise trend of content added
df.sort_values(by="date_added")
# Out:
#    show_id     type             title    director              cast  \
# 0    s0001    Movie    Sample Title 1  Director A  Actor 1, Actor 2
# 1    s0002    Movie    Sample Title 2  Director B           Actor 3
# 2    s0003    Movie    Sample Title 3  Director C               NaN
# 3    s0004    Movie    Sample Title 4         NaN  Actor 4, Actor 5
# 4    s0005    Movie    Sample Title 5  Director A  Actor 1, Actor 2
# ..     ...      ...               ...         ...               ...
# 95   s0096  TV Show   Sample Title 96         NaN  Actor 4, Actor 5
# 96   s0097  TV Show   Sample Title 97  Director A  Actor 1, Actor 2
# 97   s0098  TV Show   Sample Title 98  Director B           Actor 3
# 98   s0099  TV Show   Sample Title 99  Director C               NaN
# 99   s0100  TV Show  Sample Title 100         NaN  Actor 4, Actor 5
#
#            country  date_added  release_year rating  duration  \
# 0    United States  2020-01-01          2018  TV-MA    90 min
# ...

# %%
#📅 Time-Based:
"""Most common year of release
Netflix growth over time (date_added)"""

# %%
#Most common year of release
df["release_year"].value_counts().reset_index()
# Out:
#    release_year  count
# 0          2018     20
# 1          2019     20
# 2          2020     20
# 3          2021     20
# 4          2022     20

# %%
#Netflix growth over time (date_added)

# %%
from datetime import date

# %%
df["date_added"]=pd.to_datetime(df["date_added"])

# %%
df["date_added"]
# Out:
# 0    2020-01-01
# 1    2020-01-08
# 2    2020-01-15
# 3    2020-01-22
# 4    2020-01-29
#         ...
# 95   2021-10-27
# 96   2021-11-03
# 97   2021-11-10
# 98   2021-11-17
# 99   2021-11-24
# Name: date_added, Length: 100, dtype: datetime64[ns]

# %%
df["Year_added"]=df["date_added"].dt.year

# %%
growth=df["Year_added"].value_counts().sort_index()
plt.plot(growth.index,growth.values,marker='o')
plt.show()

# %%
df["Month"]=df["date_added"].dt.to_period('M')

# %%
"""🎭 Cast & Crew:
Most frequent directors

Frequent actors/actresses (using cast)

🔎 Filtering:
List all Indian Movies

Show all shows with rating "PG-13" released after 2015

Movies longer than 100 minutes"""
# Out:
# '🎭 Cast & Crew:\nMost frequent directors\n\nFrequent actors/actresses (using cast)\n\n🔎 Filtering:\nList all Indian Movies\n\nShow all shows with rating "PG-13" released after 2015\n\nMovies longer than 100 minutes'

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Year_added', 'Month'],
#       dtype='object')

# %%
#Most frequent directors
df["director"].value_counts()
# Out:
# director
# Director A    25
# Director B    25
# Director C    25
# Name: count, dtype: int64

# %%
#Frequent actors/actresses (using cast
df["cast"].value_counts()
# Out:
# cast
# Actor 1, Actor 2    25
# Actor 3             25
# Actor 4, Actor 5    25
# Name: count, dtype: int64

# %%
df["director"].duplicated().sum()
# Out:
# 96

# %%
df.head()
# Out:
#   show_id   type           title    director              cast  \
# 0   s0001  Movie  Sample Title 1  Director A  Actor 1, Actor 2
# 1   s0002  Movie  Sample Title 2  Director B           Actor 3
# 2   s0003  Movie  Sample Title 3  Director C               NaN
# 3   s0004  Movie  Sample Title 4         NaN  Actor 4, Actor 5
# 4   s0005  Movie  Sample Title 5  Director A  Actor 1, Actor 2
#
#           country date_added  release_year rating duration  \
# 0   United States 2020-01-01          2018  TV-MA   90 min
# 1           India 2020-01-08          2019     PG   91 min
# 2  United Kingdom 2020-01-15          2020      R   92 min
# 3          Canada 2020-01-22          2021  TV-14   93 min
# 4   United States 2020-01-29          2022   TV-G   94 min
#
#                       listed_in                               description  \
# 0  Dramas, International Movies  This is a sample description for title 1
# 1                      Comedies  This is a sample description for title 2
# ...

# %%
#List all Indian Movies
var_2=df[(df["type"]=="Movie")&(df["country"]=="India")]
print(len(var_2))    
var_2
# Out:
# 15
#    show_id   type            title    director     cast country date_added  \
# 1    s0002  Movie   Sample Title 2  Director B  Actor 3   India 2020-01-08
# 5    s0006  Movie   Sample Title 6  Director B  Actor 3   India 2020-02-05
# 9    s0010  Movie  Sample Title 10  Director B  Actor 3   India 2020-03-04
# 13   s0014  Movie  Sample Title 14  Director B  Actor 3   India 2020-04-01
# 17   s0018  Movie  Sample Title 18  Director B  Actor 3   India 2020-04-29
# 21   s0022  Movie  Sample Title 22  Director B  Actor 3   India 2020-05-27
# 25   s0026  Movie  Sample Title 26  Director B  Actor 3   India 2020-06-24
# 29   s0030  Movie  Sample Title 30  Director B  Actor 3   India 2020-07-22
# 33   s0034  Movie  Sample Title 34  Director B  Actor 3   India 2020-08-19
# 37   s0038  Movie  Sample Title 38  Director B  Actor 3   India 2020-09-16
# 41   s0042  Movie  Sample Title 42  Director B  Actor 3   India 2020-10-14
# ...

# %%
#Show all shows with rating "PG-13" released after 2015
rat=df[df["rating"]=="PG"]
rat["type"]
# Out:
# 1       Movie
# 6       Movie
# 11      Movie
# 16      Movie
# 21      Movie
# 26      Movie
# 31      Movie
# 36      Movie
# 41      Movie
# 46      Movie
# 51      Movie
# 56      Movie
# 61    TV Show
# 66    TV Show
# 71    TV Show
# 76    TV Show
# 81    TV Show
# 86    TV Show
# 91    TV Show
# 96    TV Show
# Name: type, dtype: object

# %%
# Filter only Movies
#movies_df = df[df["type"] == "Movie"]

# Remove 'min' and convert to numeric
#movies_df["duration_num"] = movies_df["duration"].str.replace(" min", "", regex=False).astype(float)

# Filter movies longer than 100 minutes
#long_movies = movies_df[movies_df["duration_num"] > 100]

#print(long_movies[["title", "duration", "duration_num"]])

# %%
#Movies longer than 100 minute
new_df=df[df["type"]=="Movie"]
new_df["Duration_m"]=new_df["duration"].str.replace("min","",regex=False).astype(float)
# Out:
# C:\Users\ladwa\AppData\Local\Temp\ipykernel_11680\1797904319.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Duration_m"]=new_df["duration"].str.replace("min","",regex=False).astype(float)

# %%
new_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Year_added', 'Month', 'Duration_m'],
#       dtype='object')

# %%
new_df[new_df["Duration_m"]>100]
# Out:
#    show_id   type            title    director              cast  \
# 11   s0012  Movie  Sample Title 12         NaN  Actor 4, Actor 5
# 12   s0013  Movie  Sample Title 13  Director A  Actor 1, Actor 2
# 13   s0014  Movie  Sample Title 14  Director B           Actor 3
# 14   s0015  Movie  Sample Title 15  Director C               NaN
# 15   s0016  Movie  Sample Title 16         NaN  Actor 4, Actor 5
# 16   s0017  Movie  Sample Title 17  Director A  Actor 1, Actor 2
# 17   s0018  Movie  Sample Title 18  Director B           Actor 3
# 18   s0019  Movie  Sample Title 19  Director C               NaN
# 19   s0020  Movie  Sample Title 20         NaN  Actor 4, Actor 5
# 20   s0021  Movie  Sample Title 21  Director A  Actor 1, Actor 2
# 21   s0022  Movie  Sample Title 22  Director B           Actor 3
# 22   s0023  Movie  Sample Title 23  Director C               NaN
# 23   s0024  Movie  Sample Title 24         NaN  Actor 4, Actor 5
# ...

# %%
#☁️ WordCloud Ideas:
"""Most used words in movie titles

Common words in descriptions"""

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
set(STOPWORDS)
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
# ...

# %%
#Most used words in movie titles
tot_title=' '.join(df["title"])

# %%
wordc=WordCloud(stopwords=set(STOPWORDS)).generate(tot_title)
plt.imshow(wordc)
plt.title("title")
# Out:
# Text(0.5, 1.0, 'title')

# %%
tot_movie=df[df["type"]=="Movie"]
tot_move=tot_movie["title"]
total_mov=' '.join(tot_move)
wc=WordCloud(background_color="white",stopwords=set(STOPWORDS)).generate(total_mov)
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
#Common words in descriptions
tot_desc=' '.join(df["description"])
wordc2=WordCloud(stopwords=set(STOPWORDS)).generate(tot_desc)
plt.imshow(wordc2)
plt.title("title")
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Year_added', 'Month'],
#       dtype='object')

# %%
#Group by rating and analyze genre trends
tv_r=df.groupby("rating")["listed_in"].value_counts().sort_index()
tv_r
# Out:
# rating  listed_in
# PG      Action & Adventure              5
#         Comedies                        5
#         Documentaries                   5
#         Dramas, International Movies    5
# R       Action & Adventure              5
#         Comedies                        5
#         Documentaries                   5
#         Dramas, International Movies    5
# TV-14   Action & Adventure              5
#         Comedies                        5
#         Documentaries                   5
#         Dramas, International Movies    5
# TV-G    Action & Adventure              5
#         Comedies                        5
#         Documentaries                   5
#         Dramas, International Movies    5
# TV-MA   Action & Adventure              5
#         Comedies                        5
#         Documentaries                   5
#         Dramas, International Movies    5
# Name: count, dtype: int64
