# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\ladwa\Desktop\excel_files\virat_stats.xlsx")

# %%
df.head()
# Out:
#    Year format  Innings  Runs  Balls  Outs   Avg    SR   HS  50  100   4s  6s  \
# 0  2011   test        9   202    473     9  22.4  42.7   63   2    0   15   2
# 1  2012   test       16   689   1474    14  49.2  46.7  116   3    3   89   2
# 2  2013   test       12   616   1127    11    56  54.7  119   3    2   73   2
# 3  2014   test       20   847   1399    19  44.6  60.5  169   2    4  101   2
# 4  2015   test       15   640   1184    15  42.7  54.1  147   2    2   74   1
#
#    Dot %
# 0   72.1
# 1   77.9
# 2   70.9
# 3   69.4
# 4   72.0

# %%
df.columns
# Out:
# Index([   'Year',  'format', 'Innings',    'Runs',   'Balls',    'Outs',
#            'Avg',      'SR',      'HS',        50,       100,      '4s',
#             '6s',   'Dot %'],
#       dtype='object')

# %%
run_y=df["Year"].value_counts().sort_index(ascending=False)
plt.bar(run_y.index,run_y.values)


plt.show()

# %%
pie_b= df.groupby(
    "4s").value_counts().sort_index()
plt.pie(pie_b,labels=pie_b.values, autopct="%1.1f%%")
plt.show()

# %%
df_p=df["4s"].value_counts().sort_index()
plt.pie(df["4s"],labels=df_p.values ,autopct="%1.1f%%")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 df_p=df["4s"].value_counts().sort_index()
# ----> 2 plt.pie(df["4s"],labels=df_p.values ,autopct="%1.1f%%")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3762, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3739 @_copy_docstring_and_deprecators(Axes.pie)
#    3740 def pie(
#    3741     x: ArrayLike,
#    (...)
#    3760     data=None,
#    3761 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3762     return gca().pie(
#    3763         x,
#    3764         explode=explode,
#    3765         labels=labels,
#    3766         colors=colors,
#    3767         autopct=autopct,
# ...
