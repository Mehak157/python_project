# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_excel(r"C:\Users\ladwa\Desktop\python_basic\demopr.xlsx")

# %%
df1.head()
# Out:
#         Date category  amount  total amount corrier service delivery  \
# 0 2025-01-01    jeans    5678        456477         deliver     done
# 1 2025-01-02    shirt    6789        456678        ontheway      not
# 2 2025-01-03    dress    1000        456879          return      not
# 3 2025-01-04    dress    3445        457080        ontheway      not
# 4 2025-01-05    watch    4566        457281         deliver     done
#
#   fullfill by   State
# 0      amazon     kkr
# 1    merchant     ynr
# 2      amazon   delhi
# 3    merchant   patna
# 4      amazon  jaipur

# %%
df1.tail()
# Out:
#          Date     category  amount  total amount corrier service delivery  \
# 19 2025-01-20        watch    7898        457482        ontheway      not
# 20 2025-01-21        dress    3456        457683          return     done
# 21 2025-01-22  accessories    1234        457884        ontheway      not
# 22 2025-01-23        shoes    5678        458085         deliver     done
# 23 2025-01-24        watch    4567        458286          return     done
#
#    fullfill by   State
# 19    merchant   delhi
# 20      amazon  jaipur
# 21    merchant  jaipur
# 22    merchant   patna
# 23      amazon     kkr

# %%
df1.columns
#df1.isnull()
df1.fillna(0)
# Out:
#          Date      category  amount  total amount corrier service delivery  \
# 0  2025-01-01         jeans    5678        456477         deliver     done
# 1  2025-01-02         shirt    6789        456678        ontheway      not
# 2  2025-01-03         dress    1000        456879          return      not
# 3  2025-01-04         dress    3445        457080        ontheway      not
# 4  2025-01-05         watch    4566        457281         deliver     done
# 5  2025-01-06        wallet    1000        457482          return     done
# 6  2025-01-07         shirt    3445        457683        ontheway      not
# 7  2025-01-08  wall hanging    4566        457884         deliver     done
# 8  2025-01-09     wallpaper    7898        458085         deliver     done
# 9  2025-01-10         jeans    3456        458286          return     done
# 10 2025-01-11         watch    1234        458487        ontheway      not
# ...

# %%
"""
data={ "name":["riva","mehar","khubi"],
      "age":[23,24,30],
      "marks":[67,76,78]
     }
df=pd.DataFrame(data)
print(df)
"""
# Out:
#     name  age  marks
# 0   riva   23     67
# 1  mehar   24     76
# 2  khubi   30     78

# %%
"""
df.rename(columns={"name":"FullName"},inplace=True)
print(df)
"""
# Out:
#   FullName  age  marks
# 0     riva   23     67
# 1    mehar   24     76
# 2    khubi   30     78

# %%
print(df1)
# Out:
#          Date      category  amount  total amount corrier service delivery  \
# 0  2025-01-01         jeans    5678        456477         deliver     done
# 1  2025-01-02         shirt    6789        456678        ontheway      not
# 2  2025-01-03         dress    1000        456879          return      not
# 3  2025-01-04         dress    3445        457080        ontheway      not
# 4  2025-01-05         watch    4566        457281         deliver     done
# 5  2025-01-06        wallet    1000        457482          return     done
# 6  2025-01-07         shirt    3445        457683        ontheway      not
# 7  2025-01-08  wall hanging    4566        457884         deliver     done
# 8  2025-01-09     wallpaper    7898        458085         deliver     done
# 9  2025-01-10         jeans    3456        458286          return     done
# 10 2025-01-11         watch    1234        458487        ontheway      not
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
names=[23,56,54,3,12,14 ]
values=[12,18,15,23,32,23]
plt.scatter(names,values)
#plt.title("Bar chart")
plt.grid(True)
plt.show()

# %%
names=[23,56,54,3,12,14 ]
values=[12,18,15,23,32,23]
plt.plot(names,values ,color="black" , marker=0
        )
plt.plot([2,3,4,5,34,21],[34,23,43,41,24,25])

#plt.title("Bar chart")
plt.show()

# %%
names=["A","B","C","D","E","F"]
values=[12,18,15,23,32,23]
plt.bar(names,values)
#plt.title("Bar chart")
plt.xlabel("Names",fontsize=14)
plt.ylabel("values",fontsize=14)
plt.show()

# %%
tags=["python","c++","java"]
size=[45,35,20]
plt.pie(size, labels=tags, autopct="%1.1f%%")
plt.show()

# %%
# %matplotlib inline
category = df1['category']
amount = df1['amount']

plt.bar(category,amount)
plt.title("ratio between category and amount")
plt.xlabel("Category",fontsize=14,color="red")
plt.grid(True)

plt.ylabel("Amount",fontsize=14,color="red")
plt.show()

# %%
df1.columns
# Out:
# Index(['Date', 'category', 'amount', 'total amount', 'corrier service',
#        'delivery', 'fullfill by', 'State'],
#       dtype='object')

# %%
service=df1["corrier service"]


# Count distinct courier services and how many times each appears
#counts = df1["corrier service"].value_counts()
counts=[9,8,7]
#print(counts)

plt.pie(counts,labels=service,autopct="%1.1f%%")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 9
#       6 counts=[9,8,7]
#       7 #print(counts)
# ----> 9 plt.pie(counts,labels=service,autopct="%1.1f%%")
#      11 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3762, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3739 @_copy_docstring_and_deprecators(Axes.pie)
#    3740 def pie(
#    3741     x: ArrayLike,
#    (...)
#    3760     data=None,
#    3761 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3762     return gca().pie(
#    3763         x,
#    3764         explode=explode,
#    3765         labels=labels,
#    3766         colors=colors,
#    3767         autopct=autopct,
# ...

# %%
service=df1["corrier service"]
counts = df1["corrier service"].value_counts()
plt.figure(figsize=(4,4))
plt.pie(counts.values, labels=counts.index, autopct="%1.1f%%",colors=["yellow","red","green"])
plt.show()

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
x=[12,32,43,35]
y=[36,65,50,29]
sns.scatterplot(x=x,y=y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[23,45,67,54,68,18]
sns.lineplot(x=x,y=y,linestyle='-',color="red")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
category=["A","B","C","D","E","F"]
values=[34,56,32,78,65,50,]
sns.barplot(x=category,y=values) 
plt.xlabel("Category")
plt.ylabel("Amount")
plt.title("Bar chart")

plt.show()
plt.savefig("barplot.png")

# %%
date=[1,2,2,2,2,3,3,3,4,4,5,5,5,5]
plt.hist(date,bins=5
         ,edgecolor="black")
plt.show()

# %%
date=[1,24,52,25,12,53,73
      ,3,4,4,5,5,5,5]
sns.histplot("date",edgecolor="black" )
plt.show()

# %%
groupA=[23,43,22,56,43]
groupB=[54,67,89,65,32,]
groupC=[35,78,75,87,23]
plt.boxplot([groupA,groupB,groupC],labels=["A","B","C"])
plt.title("BoxPlot")
plt.show()
# Out:
# C:\Users\ladwa\AppData\Local\Temp\ipykernel_6236\2513897137.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([groupA,groupB,groupC],labels=["A","B","C"])

# %%
groupA=[23,43,22,56,43]
groupB=[54,67,89,65,32,]
groupC=[35,78,75,87,23]
sns.boxplot(x=groupA,y=groupB
           )
plt.title("BoxPlot")
plt.show()

# %%
data=[[1,2,3],
      [4,5,6],
      [7,8,9]]
sns.heatmap(data,annot=True)
plt.show()
plt.title("HEATMAP EXAMPLE")
# Out:
# Text(0.5, 1.0, 'HEATMAP EXAMPLE')
